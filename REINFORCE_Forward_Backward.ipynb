# %% [markdown]
# # Enable GPU

# %%
import torch
device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')

# %% [markdown]
# # Policy Network

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class Policy(nn.Module):
  def __init__(self, in_dim, out_dim, alpha = 0.0001):
    super(Policy, self).__init__()
    self.fc1 = nn.Linear(in_dim, 128)
    self.hidden_act = nn.ReLU()
    self.fc2 = nn.Linear(128, out_dim)
    self.output_act = nn.Softmax(dim = 1)


  def forward(self, state):
    x = self.fc1(state)
    x = self.hidden_act(x)
    x = self.fc2(x)
    x = self.output_act(x)
 
    return x

# %% [markdown]
# # REINFORCE with forward and backward update

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Categorical
import numpy as np

class REINFORCE(nn.Module):
  def __init__(self, in_dim, out_dim, alpha = 0.0001, gamma = 0.99):
    super(REINFORCE, self).__init__()
    self.gamma = gamma
    self.policy = Policy(in_dim, out_dim)
    self.optimizer = torch.optim.Adam(self.policy.parameters(),lr = alpha)
    self.states = []
    self.rewards = []
    self.actions = []

  def save_episode(self, states, actions, rewards):
    self.states = torch.cat(states, dim = 0).to(device)
    self.actions = torch.tensor(actions).to(device)
    self.rewards = torch.tensor(rewards).to(device)
  
  def get_action(self, state):
    with torch.no_grad():
      prob = self.policy(state)
      distribution = Categorical(probs = prob)
      action = distribution.sample()

    return action
  
  def learn_sum_loss(self, norm_return = False): # Episodic update

    # Reverse the episode to calculate the return recursively
    self.states = self.states.flip(dims = [0])
    self.actions = self.actions.flip(dims = [0])
    self.rewards = self.rewards.flip(dims = [0])

    G = torch.tensor(0).float().to(device)
    returns = []
    for reward in self.rewards:
      G = reward + self.gamma * G
      returns.insert(0,G)
    returns = torch.tensor(returns)
    eps = np.finfo(np.float32).eps.item()
    
    returns = returns.flip(dims = [0]) # Flip it again to traverse backward
    if norm_return:
      returns = (returns - returns.mean()) / (returns.std() + eps)

    losses = []
    for state, action, G  in zip(self.states, self.actions, returns):
      state = state.unsqueeze(0)
      probs = self.policy(state)
      distr = Categorical(probs = probs)
      log_prob = distr.log_prob(action)
      loss = -log_prob * G.detach()
      losses.append(loss)
    losses = torch.cat(losses).sum().to(device)
    self.optimizer.zero_grad()
    losses.backward()
    self.optimizer.step()

    # clear the memory
    self.states = []
    self.actions = []
    self.rewards = []

  def learn_backward(self, norm_return = False):

    # Reverse the episode to calculate the return recursively
    self.states = self.states.flip(dims = [0])
    self.actions = self.actions.flip(dims = [0])
    self.rewards = self.rewards.flip(dims = [0])

    G = torch.tensor(0).float().to(device)
    returns = []
    for reward in self.rewards:
      G = reward + self.gamma * G
      returns.insert(0,G)
    returns = torch.tensor(returns)
    eps = np.finfo(np.float32).eps.item()
    
    returns = returns.flip(dims = [0]) # Flip it again to traverse backward
    if norm_return:
      returns = (returns - returns.mean()) / (returns.std() + eps)

    for state, action, G  in zip(self.states, self.actions, returns):
      state = state.unsqueeze(0)
      probs = self.policy(state)
      distr = Categorical(probs = probs)
      log_prob = distr.log_prob(action)
      loss = -log_prob * G.detach()

      self.optimizer.zero_grad()
      loss.backward()
      self.optimizer.step()

    # clear the memory
    self.states = []
    self.actions = []
    self.rewards = []
  
  def learn_forward(self, norm_return = False):
    G = torch.tensor(0).float().to(device)
    returns = []
    self.rewards = self.rewards.flip([0])
    for reward in self.rewards:
      G = reward + self.gamma * G
      returns.insert(0, G)
    returns = torch.tensor(returns)
    eps = np.finfo(np.float32).eps.item()
    if norm_return:
      returns = (returns - returns.mean()) / (returns.std() + eps)

    for state, action, G  in zip(self.states, self.actions, returns):
      state = state.unsqueeze(0)
      probs = self.policy(state)
      distr = Categorical(probs = probs)
      log_prob = distr.log_prob(action)
      loss = -log_prob * G.detach()
      self.optimizer.zero_grad()
      loss.backward()
      self.optimizer.step()

    # clear the memory
    self.states = []
    self.actions = []
    self.rewards = []

# %% [markdown]
# # Wandb is great tool to record machine learning experiment, you can further explore in detail on link below
# [Wandb](https://wandb.ai/site?gclid=CjwKCAjwlrqHBhByEiwAnLmYUGy29ZdG460eDefcxyto5hte2XmbYPmr59UQdINKtP18J8w2YbbdFxoCS6UQAvD_BwE)

# %%
# !pip install wandb
# !wandb login

# %%
import wandb
sweep_config = dict()
sweep_config['method'] = 'grid'
sweep_config['metric'] = {'name': 'running_score', 'goal': 'maximize'}
sweep_config['parameters'] = {'direction': {'values': ['backward',]}, 'learning_rate': {'values' : [0.01,0.001,0.0001,0.0003,0.00001]}
                              , 'norm_return': {'value': True}}

sweep_id = wandb.sweep(sweep_config, project = 'REINFORCE_CartPole-v1_trajectory_direction')

# %% [markdown]
# # Environment requirement for LunarLander

# %%
# !pip install box2d
# Out:
# Collecting box2d
#   Downloading Box2D-2.3.10-cp37-cp37m-manylinux1_x86_64.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 7.2 MB/s
# Installing collected packages: box2d
# Successfully installed box2d-2.3.10

# %% [markdown]
# #Without Wandb

# %%
import gym 
import torch
import time

def train():

  start = time.time()

  env = gym.make('LunarLander-v2')
  env.seed(543)
  torch.manual_seed(543)

  state_dim = env.observation_space.shape[0]
  action_dim = env.action_space.n

  device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')
  agent = REINFORCE(in_dim= state_dim,  out_dim = action_dim).to(device)
  num_ep = 3000
  print_interval = 100
  running_score = -200
  solved_scor = 200

  
  for ep in range(1, num_ep+1):
    state = env.reset()
    score = 0
    done = False
    states = []
    actions = []
    rewards = []

    while not done:
      state = torch.tensor([state]).float().to(device)
      action = agent.get_action(state)
      next_state, reward, done, _ = env.step(action.item())
      
      # saving episode
      states.append(state)
      actions.append(action.item())
      rewards.append(reward)

      # update score and state
      score += reward
      state = next_state

      if done:
        break

    # save rollout sets
    agent.save_episode(states, actions, rewards)
  
    # calculating score and running score
    running_score = 0.05 * score + (1 - 0.05) * running_score

    # train the agent
    agent.learn_backward()

    if ep % print_interval == 0:
      print('episode {} average reward {}, ended at {:.01f}'.format(ep, running_score, time.time() - start))
  save_name = 'agent_backward_with_norm_1e-4' + '.pt'
    if running_score >= solved_score:
      print('Environmnet solved at {} episode with running score of {}' .format(ep, running_score))
      break
  torch.save(agent.state_dict(),save_name)
  wandb.save(save_name)

# %%
train()

# %% [markdown]
# # Learning rate hyper parementer tuning with Wandb sweep function

# %%
import gym 
import torch
import time

def train():
  wandb.init(config = {'env':'LunarLander-v2','algorithm:': 'REINFORCE_with_norm_backward_sum_loss' },group = 'LunarLander-v2_learning_rate_tune_with_norm_backward_sum_loss')
  config = wandb.config

  start = time.time()

  env = gym.make('LunarLander-v2')
  env.seed(543)
  torch.manual_seed(543)

  state_dim = env.observation_space.shape[0]
  action_dim = env.action_space.n

  device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')
  agent = REINFORCE(in_dim= state_dim,  out_dim = action_dim, alpha= config.learning_rate).to(device)
  num_ep = 3000
  print_interval = 100
  save_interval = 1000
  running_score = 10

  wandb.watch(agent)
  for ep in range(1,num_ep+1):
    state = env.reset()
    score = 0
    done = False
    states = []
    actions = []
    rewards = []

    while not done:
      state = torch.tensor([state]).float().to(device)
      action = agent.get_action(state)
      next_state, reward, done, _ = env.step(action.item())
      
      # saving episode
      states.append(state)
      actions.append(action.item())
      rewards.append(reward)

      # update score and state
      score += reward
      state = next_state

      if done:
        break

    # save rollout sets
    agent.save_episode(states, actions, rewards)
  
    # calculating score and running score
    running_score = 0.05 * score + (1 - 0.05) * running_score
    wandb.log({'episode': ep, 'running_score': running_score})

    # train the agent
    if config.direction == 'backward':     
      agent.learn_backward(norm_return = config.norm_return)
    else:
      agent.learn_forward(norm_return = config.norm_return)

    if ep % print_interval == 0:
      print('episode {} average reward {}, ended at {:.01f}'.format(ep, running_score, time.time() - start))    
    
    if ep % save_interval == 0:
      save_name = 'agent_' + str(ep) + '.pt'
      torch.save(agent.state_dict(),save_name)
      wandb.save(save_name)

# %%
wandb.agent(sweep_id, train)
# Out:
# wandb: Agent Starting Run: 4quf8jsh with config:
# wandb: 	direction: backward
# wandb: 	learning_rate: 0.01
# wandb: 	norm_return: True
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">devoted-sweep-1</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction</a><br/>
#                 Sweep page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z</a><br/>
# Run page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/4quf8jsh" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/4quf8jsh</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210715_011236-4quf8jsh</code><br/><br/>
# episode 100 average reward -303.75036757366325, ended at 21.3
# episode 200 average reward -124.87854769462783, ended at 55.3
# episode 300 average reward -63.90707444798333, ended at 132.9
# episode 400 average reward -14.555466310927741, ended at 234.0
# episode 500 average reward 19.31030641495198, ended at 300.9
# episode 600 average reward 27.141260990588385, ended at 539.5
# episode 700 average reward -108.93207940566649, ended at 582.8
# episode 800 average reward -21.1449879772891, ended at 606.4
# episode 900 average reward 4.8439554627304116, ended at 641.6
# episode 1000 average reward 20.96273056617709, ended at 919.5
# episode 1100 average reward -73.3584114764823, ended at 987.8
# episode 1200 average reward -4.223173410563373, ended at 1063.4
# episode 1300 average reward -120.92889113085734, ended at 1096.5
# episode 1400 average reward -151.86830836553668, ended at 1122.9
# episode 1500 average reward -124.20857550517574, ended at 1146.3
# episode 1600 average reward -260.07342730049254, ended at 1170.0
# episode 1700 average reward -340.05655254732875, ended at 1193.1
# episode 1800 average reward -211.54865737366384, ended at 1290.6
# episode 1900 average reward -191.34342665562028, ended at 1343.9
# episode 2000 average reward 91.23468559657866, ended at 1502.3
# episode 2100 average reward 14.729553352102272, ended at 1607.7
# episode 2200 average reward 87.36761240482775, ended at 1648.0
# episode 2300 average reward -19.483253104901923, ended at 1776.0
# episode 2400 average reward -74.5639185777044, ended at 1829.9
# episode 2500 average reward -139.03745984963427, ended at 1860.9
# episode 2600 average reward -53.33364729691036, ended at 1900.5
# episode 2700 average reward 37.87448410987273, ended at 1937.7
# episode 2800 average reward 86.1528857889667, ended at 2094.7
# episode 2900 average reward -22.582063417679333, ended at 2173.4
# episode 3000 average reward 126.66319935089618, ended at 2334.8
# <br/>Waiting for W&B process to finish, PID 3587<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.60MB of 0.60MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210715_011236-4quf8jsh/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210715_011236-4quf8jsh/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>3000</td></tr><tr><td>running_score</td><td>126.6632</td></tr><tr><td>_runtime</td><td>2339</td></tr><tr><td>_timestamp</td><td>1626313895</td></tr><tr><td>_step</td><td>3000</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>running_score</td><td>▁▂▄▆▆▆▆▆▆▅▆▆▇▆▆▇▆▄▄▅▃▃▂▁▃▄▇█▆█▇▆▄▅▅▆▇▇▆█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 4 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">devoted-sweep-1</strong>: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/4quf8jsh" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/4quf8jsh</a><br/>
# wandb: Agent Starting Run: vsewpev5 with config:
# wandb: 	direction: backward
# wandb: 	learning_rate: 0.001
# wandb: 	norm_return: True
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">graceful-sweep-2</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction</a><br/>
#                 Sweep page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z</a><br/>
# Run page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/vsewpev5" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/vsewpev5</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210715_015142-vsewpev5</code><br/><br/>
# episode 100 average reward -134.29514254604538, ended at 29.0
# episode 200 average reward -137.02887655916405, ended at 58.4
# episode 300 average reward -126.90849370197168, ended at 94.9
# episode 400 average reward -92.75275789936575, ended at 142.5
# episode 500 average reward -71.39938548417969, ended at 198.3
# episode 600 average reward -106.96756377970522, ended at 297.0
# episode 700 average reward -49.426055465640104, ended at 409.9
# episode 800 average reward -38.34184171026469, ended at 515.6
# episode 900 average reward 5.904744088961824, ended at 642.7
# episode 1000 average reward 6.466768783909518, ended at 856.8
# episode 1100 average reward 46.335942682088344, ended at 1063.3
# episode 1200 average reward 25.47871866745521, ended at 1239.9
# episode 1300 average reward 53.35665812747767, ended at 1446.0
# episode 1400 average reward 72.31874859627632, ended at 1703.2
# episode 1500 average reward 82.82738566620671, ended at 2014.4
# episode 1600 average reward 108.5181212950028, ended at 2324.0
# episode 1700 average reward 87.27130344837377, ended at 2638.6
# episode 1800 average reward 26.906295366440187, ended at 2818.4
# episode 1900 average reward 95.40514639831537, ended at 3103.9
# episode 2000 average reward 102.14699296185226, ended at 3369.0
# episode 2100 average reward 128.9543067789045, ended at 3691.1
# episode 2200 average reward 108.35523734268743, ended at 4032.6
# episode 2300 average reward 99.26693068427885, ended at 4273.0
# episode 2400 average reward 113.4216949011597, ended at 4570.2
# episode 2500 average reward 126.63598167808416, ended at 4873.2
# episode 2600 average reward 191.83353386096232, ended at 5084.6
# episode 2700 average reward 216.8800588585992, ended at 5186.2
# episode 2800 average reward 208.70156287806458, ended at 5282.3
# episode 2900 average reward 206.1672764529265, ended at 5365.9
# episode 3000 average reward 219.37514317436455, ended at 5454.5
# <br/>Waiting for W&B process to finish, PID 4090<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.61MB of 0.61MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210715_015142-vsewpev5/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210715_015142-vsewpev5/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>3000</td></tr><tr><td>running_score</td><td>219.37514</td></tr><tr><td>_runtime</td><td>5459</td></tr><tr><td>_timestamp</td><td>1626319361</td></tr><tr><td>_step</td><td>3000</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>running_score</td><td>▁▂▁▂▂▂▃▂▂▃▃▃▄▄▅▄▄▅▅▅▆▆▆▅▅▆▆▆▆▆▆▆▆▆▇▇██▇▇</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇██████</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▇▇▇██████</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 4 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">graceful-sweep-2</strong>: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/vsewpev5" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/vsewpev5</a><br/>
# wandb: Agent Starting Run: zj5wgsi4 with config:
# wandb: 	direction: backward
# wandb: 	learning_rate: 0.0001
# wandb: 	norm_return: True
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">volcanic-sweep-3</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction</a><br/>
#                 Sweep page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z</a><br/>
# Run page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zj5wgsi4" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zj5wgsi4</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210715_032248-zj5wgsi4</code><br/><br/>
# episode 100 average reward -164.72856198270438, ended at 24.6
# episode 200 average reward -183.54893007070658, ended at 49.5
# episode 300 average reward -175.15720948592775, ended at 74.5
# episode 400 average reward -136.80611869461896, ended at 103.8
# episode 500 average reward -167.567720902479, ended at 129.4
# episode 600 average reward -164.28390855442757, ended at 155.6
# episode 700 average reward -141.1740908481412, ended at 180.5
# episode 800 average reward -144.50140495339457, ended at 206.7
# episode 900 average reward -152.3876621861411, ended at 233.6
# episode 1000 average reward -124.46374071405623, ended at 259.5
# episode 1100 average reward -181.43671132591865, ended at 286.0
# episode 1200 average reward -155.91614710299675, ended at 317.0
# episode 1300 average reward -140.86584929193776, ended at 345.8
# episode 1400 average reward -124.3608725391204, ended at 373.7
# episode 1500 average reward -147.14850101016836, ended at 402.6
# episode 1600 average reward -135.3975456639629, ended at 433.8
# episode 1700 average reward -131.14545040206306, ended at 464.1
# episode 1800 average reward -148.62612133926294, ended at 495.3
# episode 1900 average reward -135.90505651567062, ended at 526.7
# episode 2000 average reward -145.09772568267567, ended at 556.6
# episode 2100 average reward -119.80766072577298, ended at 590.3
# episode 2200 average reward -138.34533973976718, ended at 621.0
# episode 2300 average reward -133.29808366023937, ended at 652.5
# episode 2400 average reward -105.92438616495703, ended at 686.5
# episode 2500 average reward -158.81486077364312, ended at 724.0
# episode 2600 average reward -99.89058211336251, ended at 758.2
# episode 2700 average reward -102.98416817170374, ended at 795.2
# episode 2800 average reward -120.67833643380888, ended at 830.5
# episode 2900 average reward -118.53171605506424, ended at 866.8
# episode 3000 average reward -109.25307228199306, ended at 903.5
# <br/>Waiting for W&B process to finish, PID 5203<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.62MB of 0.62MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210715_032248-zj5wgsi4/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210715_032248-zj5wgsi4/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>3000</td></tr><tr><td>running_score</td><td>-109.25307</td></tr><tr><td>_runtime</td><td>907</td></tr><tr><td>_timestamp</td><td>1626320275</td></tr><tr><td>_step</td><td>3000</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>running_score</td><td>▃▃▃▃▅▄▁▁▃▆▅▅▃▆▁▅▄▅▆▅▅▆▄▅▅▃▅▆▅▆▅▇▇▅▇█▇▇▆█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 4 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">volcanic-sweep-3</strong>: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zj5wgsi4" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zj5wgsi4</a><br/>
# wandb: Agent Starting Run: zi5j9uie with config:
# wandb: 	direction: backward
# wandb: 	learning_rate: 0.0003
# wandb: 	norm_return: True
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">noble-sweep-4</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction</a><br/>
#                 Sweep page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z</a><br/>
# Run page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zi5j9uie" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zi5j9uie</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210715_033802-zi5j9uie</code><br/><br/>
# episode 100 average reward -159.06387039071151, ended at 28.9
# episode 200 average reward -181.3431972361139, ended at 55.6
# episode 300 average reward -160.16067359041085, ended at 82.0
# episode 400 average reward -147.67231233776636, ended at 109.7
# episode 500 average reward -149.8437460257715, ended at 139.0
# episode 600 average reward -130.42763445143748, ended at 168.1
# episode 700 average reward -139.74931243893477, ended at 201.9
# episode 800 average reward -137.7861057961989, ended at 235.3
# episode 900 average reward -133.2849392767632, ended at 268.0
# episode 1000 average reward -82.07091493428936, ended at 304.2
# episode 1100 average reward -92.44248167633138, ended at 340.0
# episode 1200 average reward -76.87109183523879, ended at 375.6
# episode 1300 average reward -74.14915720542636, ended at 417.0
# episode 1400 average reward -81.39843444679369, ended at 464.0
# episode 1500 average reward -54.20164263117405, ended at 518.8
# episode 1600 average reward -62.76601566528076, ended at 576.7
# episode 1700 average reward -64.65438411932716, ended at 636.9
# episode 1800 average reward -79.82534261205323, ended at 736.0
# episode 1900 average reward -37.62828248579852, ended at 842.7
# episode 2000 average reward -47.81077182059958, ended at 942.7
# episode 2100 average reward -40.569298793724194, ended at 1051.3
# episode 2200 average reward -44.300259001457675, ended at 1166.0
# episode 2300 average reward -36.988811459826856, ended at 1289.8
# episode 2400 average reward -30.358947059014653, ended at 1446.0
# episode 2500 average reward -26.599957915420177, ended at 1613.6
# episode 2600 average reward -6.346203608609714, ended at 1782.8
# episode 2700 average reward -4.211566859021993, ended at 1955.0
# episode 2800 average reward 14.95543779469047, ended at 2129.3
# episode 2900 average reward 2.104237670006652, ended at 2305.2
# episode 3000 average reward 0.49728700378458585, ended at 2503.3
# <br/>Waiting for W&B process to finish, PID 5424<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.64MB of 0.64MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210715_033802-zi5j9uie/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210715_033802-zi5j9uie/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>3000</td></tr><tr><td>running_score</td><td>0.49729</td></tr><tr><td>_runtime</td><td>2508</td></tr><tr><td>_timestamp</td><td>1626322790</td></tr><tr><td>_step</td><td>3000</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>running_score</td><td>▂▂▂▂▂▂▁▂▂▂▂▄▃▄▃▄▅▅▄▅▅▅▅▃▅▆▆▆▆▆▆▆▇▇▇▇▇█▇█</td></tr><tr><td>_runtime</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▇▇▇█</td></tr><tr><td>_timestamp</td><td>▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▆▆▆▇▇▇█</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 4 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">noble-sweep-4</strong>: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zi5j9uie" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/zi5j9uie</a><br/>
# wandb: Agent Starting Run: guknz0ao with config:
# wandb: 	direction: backward
# wandb: 	learning_rate: 1e-05
# wandb: 	norm_return: True
#                 Tracking run with wandb version 0.10.33<br/>
#                 Syncing run <strong style="color:#cdcd00">fresh-sweep-5</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction</a><br/>
#                 Sweep page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/sweeps/mx3gr92z</a><br/>
# Run page: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/guknz0ao" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/guknz0ao</a><br/>
#                 Run data is saved locally in <code>/content/wandb/run-20210715_041957-guknz0ao</code><br/><br/>
# episode 100 average reward -208.60064287858745, ended at 22.5
# episode 200 average reward -185.7003518889347, ended at 46.5
# episode 300 average reward -215.8511851725121, ended at 69.6
# episode 400 average reward -162.87546545804145, ended at 93.3
# episode 500 average reward -169.4592676827227, ended at 117.2
# episode 600 average reward -205.85435721002295, ended at 140.8
# episode 700 average reward -140.94634505187648, ended at 164.0
# episode 800 average reward -187.3608647027201, ended at 189.8
# episode 900 average reward -174.61129462061092, ended at 213.3
# episode 1000 average reward -201.37417945768257, ended at 237.2
# episode 1100 average reward -181.42273713352273, ended at 260.7
# episode 1200 average reward -173.6218164789308, ended at 284.3
# episode 1300 average reward -187.8597980755604, ended at 307.6
# episode 1400 average reward -175.05629952547199, ended at 332.2
# episode 1500 average reward -159.457675868082, ended at 356.1
# episode 1600 average reward -197.1852464176528, ended at 379.9
# episode 1700 average reward -163.54559325867993, ended at 405.2
# episode 1800 average reward -202.56429307380085, ended at 429.0
# episode 1900 average reward -206.0635706751075, ended at 453.2
# episode 2000 average reward -175.69852422366623, ended at 477.7
# episode 2100 average reward -184.23057987058021, ended at 500.9
# episode 2200 average reward -192.0416033263919, ended at 524.3
# episode 2300 average reward -213.59378093570757, ended at 555.2
# episode 2400 average reward -159.6783993032563, ended at 578.7
# episode 2500 average reward -196.21486341948693, ended at 606.9
# episode 2600 average reward -178.09852624570723, ended at 632.2
# episode 2700 average reward -182.899694454041, ended at 657.0
# episode 2800 average reward -173.11364935627918, ended at 680.8
# episode 2900 average reward -161.8059996946803, ended at 705.0
# episode 3000 average reward -179.7467300306776, ended at 730.3
# <br/>Waiting for W&B process to finish, PID 5959<br/>Program ended successfully.
# VBox(children=(Label(value=' 0.65MB of 0.65MB uploaded (0.00MB deduped)\r'), FloatProgress(value=1.0, max=1.0)…
# Find user logs for this run at: <code>/content/wandb/run-20210715_041957-guknz0ao/logs/debug.log</code>
# Find internal logs for this run at: <code>/content/wandb/run-20210715_041957-guknz0ao/logs/debug-internal.log</code>
# <h3>Run summary:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>3000</td></tr><tr><td>running_score</td><td>-179.74673</td></tr><tr><td>_runtime</td><td>734</td></tr><tr><td>_timestamp</td><td>1626323532</td></tr><tr><td>_step</td><td>3000</td></tr></table>
# <h3>Run history:</h3><br/><style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     </style><table class="wandb">
# <tr><td>episode</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>running_score</td><td>█▃▄▇▃▅▃▃▂▇▄▃▄▃▁▂▂▅▅▆▃▃▄▄▄▃▅▅▅▄▄▅▄▅▄▇▆▅▇▃</td></tr><tr><td>_runtime</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_timestamp</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>_step</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr></table><br/>
# Synced 5 W&B file(s), 1 media file(s), 2 artifact file(s) and 4 other file(s)
#                     <br/>Synced <strong style="color:#cdcd00">fresh-sweep-5</strong>: <a href="https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/guknz0ao" target="_blank">https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/runs/guknz0ao</a><br/>
# wandb: Sweep Agent: Waiting for job.
# wandb: Sweep Agent: Exiting.

# %% [markdown]
# # You can check out the result for comparing forward and backward algorithm for REINFORCE with hyper parameter tuning
#
# [Link for Report](https://https://wandb.ai/ko120/REINFORCE_CartPole-v1_trajectory_direction/reports/REINFORCE-Updating-direction-variation--Vmlldzo4NDMxMDQ)

# %% [markdown]
# # Visualize agent before train

# %%
# For visualization (rendering OpenAI Gym)
# !apt-get install -y xvfb python-opengl ffmpeg > /dev/null 2>&1
# !apt-get install ffmpeg freeglut3-dev xvfb  
# !pip install -U colabgymrender

# %%
# For visualization, must set this up to make virtual displaying screen on Colab, otherwise, it fails
import os
os.system("Xvfb :1 -screen 0 1024x768x24 &")
os.environ['DISPLAY'] = ':1'

# %%
import gym
from colabgymrender.recorder import Recorder

env = gym.make("LunarLander-v2")
directory = '/content/videos'

torch.manual_seed(543)

env = Recorder(env, directory)


state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')
agent = REINFORCE(in_dim= state_dim,  out_dim = action_dim).to(device)

state = env.reset()
terminal = False
while not terminal:
  state = torch.tensor(state).unsqueeze(0).to(device)
  action = agent.get_action(state)
  next_state, reward, terminal, info = env.step(action.item())
  state = next_state

env.play()
# Out:
# <video controls>
#  <source src="...

# %% [markdown]
# # Visualize best performing forward trained agent (lr= 1e-4) without normalization return

# %%
import gym
from colabgymrender.recorder import Recorder

env = gym.make("LunarLander-v2")
directory = '/content/videos'

torch.manual_seed(543)

env = Recorder(env, directory)


state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')
agent = REINFORCE(in_dim= state_dim,  out_dim = action_dim).to(device)

agent.load_state_dict(torch.load('agent_forward_withoutnorm_1e-4.pt'))
agent.eval()


state = env.reset()
terminal = False
while not terminal:
  state = torch.tensor(state).unsqueeze(0).to(device)
  action = agent.get_action(state)
  next_state, reward, terminal, info = env.step(action.item())
  state = next_state

env.play()
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.
# <video controls>
#  <source src="...

# %% [markdown]
# # Visualize best performing backward trained agent (lr= 1e-4) with normalization return

# %%
import gym
from colabgymrender.recorder import Recorder

env = gym.make("LunarLander-v2")
directory = '/content/videos'



env = Recorder(env, directory)


state_dim = env.observation_space.shape[0]
action_dim = env.action_space.n

device = torch.device('cuda:0' if torch.cuda.is_available else 'cpu')
agent = REINFORCE(in_dim= state_dim,  out_dim = action_dim).to(device)

agent.load_state_dict(torch.load('agent_backward_with_norm_1e-4.pt'))
agent.eval()

state = env.reset()
terminal = False
while not terminal:
  state = torch.tensor(state).unsqueeze(0).to(device)
  action = agent.get_action(state)
  next_state, reward, terminal, info = env.step(action.item())
  state = next_state

env.play()
# Out:
# <video controls>
#  <source src="...
